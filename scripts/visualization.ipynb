# %% [markdown]
# <h1>Spotify data insights </h1>
#
# 1. kaggle data
# 2. offers insights about music trends, artist popularity, and genres

# %% [markdown]
# <h3>Data Cleaning </h3>

# %%
import pandas as pd

df = pd.read_csv('spotify_data.csv')

print("dataset preview: ")
print(df.head(5))
# Out:
# dataset preview:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity  explicit artist_name  artist_popularity  \
# 0             4                 0      True       Diplo                 77
# 1             1                 0      True    Yelawolf                 64
# 2             1                 4      True   Riff Raff                 48
# 3             8                30      True       Diplo                 77
# 4             2                 0      True     Rumelis                 48
#
# ...

# %%
print("dataset info: ")
df.info()
print("dataset shape: ")
df.shape

df.describe(include='all')
# Out:
# dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8582 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8582 non-null   object
#  1   track_name          8582 non-null   object
#  2   track_number        8582 non-null   int64
#  3   track_popularity    8582 non-null   int64
#  4   explicit            8582 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8582 non-null   int64
#  7   artist_followers    8582 non-null   int64
#  8   artist_genres       5221 non-null   object
#  9   album_id            8582 non-null   object
#  10  album_name          8582 non-null   object
#  11  album_release_date  8582 non-null   object
#  12  album_total_tracks  8582 non-null   int64
#  13  album_type          8582 non-null   object
#  14  track_duration_min  8582 non-null   float64
# ...

# %%
import numpy as np

df1 = df.replace('7', np.nan)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8582 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8582 non-null   object
#  1   track_name          8582 non-null   object
#  2   track_number        8582 non-null   int64
#  3   track_popularity    8582 non-null   int64
#  4   explicit            8582 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8582 non-null   int64
#  7   artist_followers    8582 non-null   int64
#  8   artist_genres       5221 non-null   object
#  9   album_id            8582 non-null   object
#  10  album_name          8576 non-null   object
#  11  album_release_date  8582 non-null   object
#  12  album_total_tracks  8582 non-null   int64
#  13  album_type          8582 non-null   object
#  14  track_duration_min  8582 non-null   float64
# ...

# %%
#finding missing values in each column
missing_values = df1.isnull().sum()
print("Missing values in each column:")
print(missing_values)


missing_prcent = (df1.isnull().sum() / len(df1)) * 100
print("Percentage of missing values in each column:")
print(missing_prcent)
# Out:
# Missing values in each column:
# track_id                 0
# track_name               0
# track_number             0
# track_popularity         0
# explicit                 0
# artist_name              3
# artist_popularity        0
# artist_followers         0
# artist_genres         3361
# album_id                 0
# album_name               6
# album_release_date       0
# album_total_tracks       0
# album_type               0
# track_duration_min       0
# dtype: int64
# Percentage of missing values in each column:
# track_id               0.000000
# track_name             0.000000
# track_number           0.000000
# track_popularity       0.000000
# explicit               0.000000
# artist_name            0.034957
# artist_popularity      0.000000
# artist_followers       0.000000
# artist_genres         39.163365
# album_id               0.000000
# album_name             0.069914
# album_release_date     0.000000
# album_total_tracks     0.000000
# ...

# %% [markdown]
# <h3>handling missing values </h3>
#
# artist_name =  3 missing (MCAR) //drpoping rows
#
# album_name = 6missing (MCAR) //filling them with unknown
#
# artist_genres = 39% missing (MNAR)// unknown

# %%
df1 = df1.dropna(subset=['artist_name'])
df1['album_name'] = df1['album_name'].fillna('Unknown Album')
df1['artist_genres'] = df1['artist_genres'].fillna('Uncategorized')

df1.info()
print(df1.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8579 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8579 non-null   object
#  1   track_name          8579 non-null   object
#  2   track_number        8579 non-null   int64
#  3   track_popularity    8579 non-null   int64
#  4   explicit            8579 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8579 non-null   int64
#  7   artist_followers    8579 non-null   int64
#  8   artist_genres       8579 non-null   object
#  9   album_id            8579 non-null   object
#  10  album_name          8579 non-null   object
#  11  album_release_date  8579 non-null   object
#  12  album_total_tracks  8579 non-null   int64
#  13  album_type          8579 non-null   object
#  14  track_duration_min  8579 non-null   float64
# ...

# %%
# Converting data types
df1['album_release_date'] = pd.to_datetime(df1['album_release_date'])
df1['album_type'] = df1['album_type'].astype('category')

# Extracting year from release date : feature engineering
df1['release_year'] = df1['album_release_date'].dt.year

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8579 entries, 0 to 8581
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8579 non-null   object
#  1   track_name          8579 non-null   object
#  2   track_number        8579 non-null   int64
#  3   track_popularity    8579 non-null   int64
#  4   explicit            8579 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8579 non-null   int64
#  7   artist_followers    8579 non-null   int64
#  8   artist_genres       8579 non-null   object
#  9   album_id            8579 non-null   object
#  10  album_name          8579 non-null   object
#  11  album_release_date  8579 non-null   datetime64[ns]
#  12  album_total_tracks  8579 non-null   int64
#  13  album_type          8579 non-null   category
#  14  track_duration_min  8579 non-null   float64
# ...

# %%
#saving cleaned data to a new csv file
df1.to_csv('cleaded_data.csv', index = False)

# %% [markdown]
# <h2>DATA VISUALIZATION </h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ensure release_year exists
if 'release_year' not in df1.columns:
	df1['album_release_date'] = pd.to_datetime(df1['album_release_date'], errors='coerce')
	df1['release_year'] = df1['album_release_date'].dt.year

#popularity distribution
plt.figure(figsize=(10,6))
sns.histplot(df1['track_popularity'], bins=30, kde=True)
plt.title('Distribution of Song Popularity')
plt.xlabel('Track Popularity')
plt.ylabel('Frequency')
plt.show()
plt.savefig('popularity_distribution.png')

# Number of songs released each year
plt.figure(figsize=(12,6))
year_order = sorted(df1['release_year'].dropna().unique())
sns.countplot(x='release_year', data=df1, palette='coolwarm', order=year_order)
plt.title('Number of Songs Released Each Year')
plt.xlabel('Release Year')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45)
plt.show()
plt.savefig('songs_per_year.png')

# Top 10 Artists by Number of Songs
plt.figure(figsize=(12,6))
top_artists = df1['artist_name'].value_counts().head(10)
sns.barplot(x=top_artists.index, y=top_artists.values, palette='magma')
plt.title('Top 10 Artists by Number of Songs')
plt.xlabel('Artist Name')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45)
plt.show()
plt.savefig('top_artists_songs.png')

# Top 10 Artists by Total Followers
top_artists = df1[['artist_name', 'artist_followers']].drop_duplicates().nlargest(10, 'artist_followers')

plt.figure(figsize=(12, 6))
sns.barplot(data=top_artists, x='artist_followers', y='artist_name', palette='viridis')
plt.title('Top Artists by Total Followers')
plt.xlabel('Followers (Millions)')
plt.ylabel('Artist Name')
plt.show()
plt.savefig('top_artists_followers.png')

# Explicit vs. Non-Explicit Track Popularity
plt.figure(figsize=(8, 6))
sns.boxplot(x='explicit', y='track_popularity', data=df1, palette='Set2')
plt.title('Popularity: Explicit vs. Non-Explicit Tracks')
plt.xlabel('Is Explicit?')
plt.ylabel('Track Popularity')
plt.show()
plt.savefig('explicit_vs_popularity.png')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\2117114753.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='release_year', data=df1, palette='coolwarm', order=year_order)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\2117114753.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_artists.index, y=top_artists.values, palette='magma')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6008\2117114753.py:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# correlation heatmap
plt.figure(figsize=(10, 8))
# Select only numeric columns for correlation
corr = df[['track_popularity', 'artist_popularity', 'artist_followers', 'track_duration_min', 'album_total_tracks']].corr()
sns.heatmap(corr, annot=True, cmap='BuPu', fmt=".2f")
plt.title('Correlation Between Music Metrics')
plt.savefig('correlation_matrix.png')

# %% [markdown]
# <h3>Trends Within The Dataset</h3>
#
# 1. Track popularity distribution: Shows that most songs have a popularity score of 60 and 80 with a significant spike of songs at 0
#
# 2. Release trends: Displays an exponential growth in the number of songs released per year peaking in 2024/2025. this reflects the modern 'streaming era' where music is produced and uploaded more frequently than in the 20th century
#
# 3. Top artists char: Taylor swift dominates both the number of songs and total followers and other top artist include Ed Sheeran, Billie Eilish
#
# 4. Boxplot: popularity: Explicit vs non-explicit tracks' compares the popularity scores of songs based on whether they contain explicit content. explicit tracks are significantly less popular (explicit: unsuitable for children, with swear words, mature themes, sexual content)
#
# 5. Correlation heatmap: The strongest relationship is between Artist popularity ans Artist follower(0.64). interestingly track duration and the total number of tracks on an album have no impact on popularity
